# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('data.csv')

# %%
df.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
plt.scatter(df['YearsExperience'], df['Salary'])

# %%
from sklearn.linear_model import LinearRegression

# %%
X = df[['YearsExperience']]
Y = df['Salary']

# %%
model = LinearRegression()

# %%
df[['YearsExperience', 'Salary']]
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
model.predict(X)
# Out:
# array([ 36187.15875227,  38077.15121656,  39967.14368085,  44692.12484158,
#         46582.11730587,  53197.09093089,  54142.08716303,  56032.07962732,
#         56032.07962732,  60757.06078805,  62647.05325234,  63592.04948449,
#         63592.04948449,  64537.04571663,  68317.03064522,  72097.0155738 ,
#         73987.00803809,  75877.00050238,  81546.97789525,  82491.9741274 ,
#         90051.94398456,  92886.932681  , 100446.90253816, 103281.8912346 ,
#        108006.87239533, 110841.86109176, 115566.84225249, 116511.83848464,
#        123126.81210966, 125016.80457395])

# %%
slope = model.coef_
slope
#Rate of change of salary with respect to years of experience
# Out:
# array([9449.96232146])

# %%
intercept = model.intercept_
intercept
#Salary when years of experience is 0
# Out:
# np.float64(25792.20019866871)

# %%
# X=df.drop("Target col",axis=0)
# Y=df[target col]

# %%
#scenarion 1: X and Y are inputs  and to predict the target variable output which is unseen data(learns the patterns from X and Y 100% data)Evaluate(X and Y)
#scenarion 2: X is input and Y is output and to predict the target variable output which is unseen data

# %%
from sklearn.model_selection import train_test_split

# %%
train_test_split(X,Y,train_size=0.8)
# Out:
# [    YearsExperience
#  10              3.9
#  20              6.8
#  12              4.0
#  11              4.0
#  19              6.0
#  9               3.7
#  2               1.5
#  13              4.1
#  4               2.2
#  7               3.2
#  5               2.9
#  8               3.2
#  18              5.9
#  28             10.3
#  6               3.0
#  16              5.1
#  0               1.1
#  14              4.5
#  29             10.5
#  3               2.0
#  23              8.2
#  25              9.0
#  22              7.9
#  21              7.1,
#      YearsExperience
#  27              9.6
#  17              5.3
#  24              8.7
#  26              9.5
#  15              4.9
#  1               1.3,
#  10     63218.0
#  20     91738.0
#  12     56957.0
#  11     55794.0
#  19     93940.0
#  9      57189.0
#  2      37731.0
#  13     57081.0
#  4      39891.0
#  7      54445.0
#  5      56642.0
#  8      64445.0
#  18     81363.0
#  28    122391.0
# ...

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,train_size=0.8,random_state=42)
X_train
# Out:
#     YearsExperience
# 28             10.3
# 24              8.7
# 12              4.0
# 0               1.1
# 4               2.2
# 16              5.1
# 5               2.9
# 13              4.1
# 11              4.0
# 22              7.9
# 1               1.3
# 2               1.5
# 25              9.0
# 3               2.0
# 21              7.1
# 26              9.5
# 18              5.9
# 29             10.5
# 20              6.8
# 7               3.2
# 10              3.9
# 14              4.5
# 19              6.0
# 6               3.0

# %%
Y_test
# Out:
# 27    112635.0
# 15     67938.0
# 23    113812.0
# 17     83088.0
# 8      64445.0
# 9      57189.0
# Name: Salary, dtype: float64

# %%
model = LinearRegression()

# %%
model.fit([X_train,Y_test])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 model.fit([X_train,Y_test])
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# TypeError: LinearRegression.fit() missing 1 required positional argument: 'y'

# %%
# Y_pred = model.predict(X_train)

# %%
# Error = Y_train-Y_pred

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,root_mean_squared_error,r2_score

# %%
#syntax for metrics
#metricname(ytrain,ypred)
model = LinearRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
model.predict(X)
# Out:
# array([ 35687.77986711,  37572.54293172,  39457.30599632,  44169.21365784,
#         46053.97672244,  52650.64744857,  53593.02898087,  55477.79204548,
#         55477.79204548,  60189.69970699,  62074.4627716 ,  63016.8443039 ,
#         63016.8443039 ,  63959.2258362 ,  67728.75196542,  71498.27809463,
#         73383.04115923,  75267.80422384,  80922.09341766,  81864.47494996,
#         89403.52720839,  92230.6718053 ,  99769.72406372, 102596.86866063,
#        107308.77632215, 110135.92091906, 114847.82858057, 115790.21011287,
#        122386.880839  , 124271.6439036 ])

# %%
ypred_train=model.predict(X_train)
score=r2_score(Y_train,ypred_train)
score
# Out:
# 0.9645401573418146

# %%
# ypred_test=model.predict(X_test)
# scroe=r2_score(Y_train,ypred_train)
# score

# %%
plt.scatter(X_train,Y_train)
plt.scatter(X_train,ypred_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 plt.scatter(X_train,Y_train)
# ----> 2 plt.scatter(X_train,ypred_train)
#
# NameError: name 'ypred_train' is not defined
